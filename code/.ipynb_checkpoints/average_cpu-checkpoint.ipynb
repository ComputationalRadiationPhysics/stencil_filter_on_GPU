# %%
# load needed modules
import numba 
import numpy as np

import time

import numpy as np
from numba import cuda
from math import ceil 

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#print out gpu information
# !hostname
gpu = numba.cuda.get_current_device()
print("name = %s" % gpu.name)
print("maxThreadsPerBlock = %s" % str(gpu.MAX_THREADS_PER_BLOCK))
print("maxBlockDimX = %s" % str(gpu.MAX_BLOCK_DIM_X))
print("maxBlockDimY = %s" % str(gpu.MAX_BLOCK_DIM_Y))
print("maxBlockDimZ = %s" % str(gpu.MAX_BLOCK_DIM_Z))
print("maxGridDimX = %s" % str(gpu.MAX_GRID_DIM_X))
print("maxGridDimY = %s" % str(gpu.MAX_GRID_DIM_Y))
print("maxGridDimZ = %s" % str(gpu.MAX_GRID_DIM_Z))
print("maxSharedMemoryPerBlock = %s" % str(gpu.MAX_SHARED_MEMORY_PER_BLOCK))
print("asyncEngineCount = %s" % str(gpu.ASYNC_ENGINE_COUNT))
print("canMapHostMemory = %s" % str(gpu.CAN_MAP_HOST_MEMORY))
print("multiProcessorCount = %s" % str(gpu.MULTIPROCESSOR_COUNT))
print("warpSize = %s" % str(gpu.WARP_SIZE))
print("unifiedAddressing = %s" % str(gpu.UNIFIED_ADDRESSING))
print("pciBusID = %s" % str(gpu.PCI_BUS_ID))
print("pciDeviceID = %s" % str(gpu.PCI_DEVICE_ID))
# Out:
# ---------------------------------------------------------------------------
# CudaAPIError                              Traceback (most recent call last)
# ~/gpu_code/numba_project/k80_numba/lib/python3.6/site-packages/numba/cuda/cudadrv/driver.py in initialize(self)
#     230             _logger.info('init')
# --> 231             self.cuInit(0)
#     232         except CudaAPIError as e:
#
# ~/gpu_code/numba_project/k80_numba/lib/python3.6/site-packages/numba/cuda/cudadrv/driver.py in safe_cuda_api_call(*args)
#     293             retcode = libfn(*args)
# --> 294             self._check_error(fname, retcode)
#     295         return safe_cuda_api_call
#
# ~/gpu_code/numba_project/k80_numba/lib/python3.6/site-packages/numba/cuda/cudadrv/driver.py in _check_error(self, fname, retcode)
#     328                     raise CudaDriverError("CUDA initialized before forking")
# --> 329             raise CudaAPIError(retcode, msg)
#     330
#
# CudaAPIError: [803] Call to cuInit results in UNKNOWN_CUDA_ERROR
#
# During handling of the above exception, another exception occurred:
#
# CudaSupportError                          Traceback (most recent call last)
# <ipython-input-2-fd43ca01d0b6> in <module>
#       1 #print out gpu information
#       2
# ----> 3 gpu = numba.cuda.get_current_device()
#       4 print("name = %s" % gpu.name)
#       5 print("maxThreadsPerBlock = %s" % str(gpu.MAX_THREADS_PER_BLOCK))
#
# ~/gpu_code/numba_project/k80_numba/lib/python3.6/site-packages/numba/cuda/api.py in get_current_device()
#     314 def get_current_device():
#     315     "Get current device associated with the current thread"
# --> 316     return current_context().device
#     317
#     318
#
# ~/gpu_code/numba_project/k80_numba/lib/python3.6/site-packages/numba/cuda/cudadrv/devices.py in get_context(devnum)
#     211     return the CUDA context.
#     212     """
# --> 213     return _runtime.get_or_create_context(devnum)
#     214
#     215
#
# ~/gpu_code/numba_project/k80_numba/lib/python3.6/site-packages/numba/cuda/cudadrv/devices.py in get_or_create_context(self, devnum)
#     137             attached_ctx = self._get_attached_context()
#     138             if attached_ctx is None:
# --> 139                 return self._get_or_create_context_uncached(devnum)
#     140             else:
#     141                 return attached_ctx
#
# ~/gpu_code/numba_project/k80_numba/lib/python3.6/site-packages/numba/cuda/cudadrv/devices.py in _get_or_create_context_uncached(self, devnum)
#     150             # Try to get the active context in the CUDA stack or
#     151             # activate GPU-0 with the primary context
# --> 152             with driver.get_active_context() as ac:
#     153                 if not ac:
#     154                     return self._activate_context_for(0)
#
# ~/gpu_code/numba_project/k80_numba/lib/python3.6/site-packages/numba/cuda/cudadrv/driver.py in __enter__(self)
#     385         else:
#     386             hctx = drvapi.cu_context(0)
# --> 387             driver.cuCtxGetCurrent(byref(hctx))
#     388             hctx = hctx if hctx.value else None
#     389
#
# ~/gpu_code/numba_project/k80_numba/lib/python3.6/site-packages/numba/cuda/cudadrv/driver.py in __getattr__(self, fname)
#     272         # Initialize driver
#     273         if not self.is_initialized:
# --> 274             self.initialize()
#     275
#     276         if self.initialization_error is not None:
#
# ~/gpu_code/numba_project/k80_numba/lib/python3.6/site-packages/numba/cuda/cudadrv/driver.py in initialize(self)
#     232         except CudaAPIError as e:
#     233             self.initialization_error = e
# --> 234             raise CudaSupportError("Error at driver init: \n%s:" % e)
#     235         else:
#     236             self.pid = _getpid()
#
# CudaSupportError: Error at driver init:
# [803] Call to cuInit results in UNKNOWN_CUDA_ERROR:

# %%
#generate dummy data for test

Nz, Ny, Nx = 128, 512, 128

real_data = (np.ones((Nz, Ny, Nx)) * np.sin(np.linspace(0, 20, Ny)[np.newaxis, :, np.newaxis])*0.5 
             + np.random.normal(scale=1.0, size=(Nz, Ny, Nx)) )

# %%
#visulize date: before filtering:

plt.pcolormesh(real_data[Nz//2,:, :], vmin=-2, vmax=2, cmap=plt.cm.jet)

cb = plt.colorbar()
for i in cb.ax.get_yticklabels():
    i.set_fontsize(14)
    
plt.xlabel("x-index", fontsize=18)
plt.xticks( fontsize=14)
plt.ylabel("y-index", fontsize=18)
plt.yticks( fontsize=14)

plt.tight_layout()

plt.show()

# %%
#cpu version: function

@numba.njit
def numba_mean(array):
    return np.mean(array)

@numba.njit
def cpu_smooth_kernel(input_data, output_data, fkt, stencil):
    # data size
    Nz, Ny, Nx = np.shape(input_data)
    # stencil size
    dx = stencil[0]
    dy = stencil[1]
    dz = stencil[2]
    # run over all data
    for z_id in range(Nz):
        z_min = max(z_id-dz, 0)
        z_max = min(z_id+dz+1, Nz)
        for y_id in range(Ny):
            y_min = max(y_id-dy, 0)
            y_max = min(y_id+dy+1, Ny)
            for x_id in range(Nx):
                x_min = max(x_id-dx, 0)
                x_max = min(x_id+dx+1, Nx)

                output_data[z_id, y_id, x_id] = fkt(input_data[z_min:z_max, y_min:y_max, x_min:x_max])

# %%
# define the output result: same size of input data
output_data = real_data.copy()

#define the stencil size (3D)
stencil = (8, 6, 8)

# %%
#calculate the runtime of cpu version

start = time.time()
cpu_smooth_kernel(real_data, output_data, numba_mean, stencil)
end = time.time()
print("Elapsed (cpu with compilation) = %s" % (end - start))

start = time.time()
cpu_smooth_kernel(real_data, output_data, numba_mean, stencil)
end = time.time()
print("Elapsed (cpu without compilation) = %s" % (end - start))

# cpu baseline(mean):
# Elapsed (cpu with compilation) = 65.07919216156006
# Elapsed (cpu without compilation) = 61.09115695953369
# Out:
# Elapsed (cpu with compilation) = 65.07919216156006
# Elapsed (cpu without compilation) = 61.09115695953369
